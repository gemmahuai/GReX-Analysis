# %%
from grex_utils.io import read_voltage_as_stokesi
import matplotlib.pyplot as plt

# %%
stokesi = read_voltage_as_stokesi("/hdd/data/voltages/grex_dump-20240320T052920.nc")

# %%
# ?read_voltage_as_stokesi
# Out:
# Signature:
# read_voltage_as_stokesi(
#     file_name: str,
#     time_downsample: Optional[int] = None,
#     freq_downsample: Optional[int] = None,
#     time_chunks: int = 2048,
# ) -> xarray.core.dataarray.DataArray
# Docstring:
# Read in the voltage data from a .nc file
# and return it as Stokes intensity.
#
# Parameters
# ----------
# file_name
#     The file name of the .nc file with voltages
# time_downsample
#     The factor to downsample in time
# freq_downsample
#     The factor to downsample in frequency
# time_chunks
#     The netcdf reader chunk size in the time dimension
#
# Returns
# -------
# stokesi
#     The Stokes I data object
# File:      ~/.local/lib/python3.10/site-packages/grex_utils/io.py
# Type:      function

# %%
stokesi.mean("time").plot()
